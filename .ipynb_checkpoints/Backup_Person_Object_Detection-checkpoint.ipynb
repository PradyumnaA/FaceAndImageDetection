# %%
import cv2
import numpy as np
import os

# Load DNN object detection model
net = cv2.dnn.readNetFromTensorflow(
    'models/frozen_inference_graph.pb',
    'models/ssd_mobilenet_v2_coco_2018_03_29.pbtxt'
)

# Load COCO class labels
with open('models/coco_class_labels.txt', 'r') as f:
    class_names = f.read().strip().split('\n')

# Object label filtering to avoid bicycle/head false positives
allowed_objects = {'cell phone', 'cup', 'bottle', 'pen', 'remote', 'wallet', 'book'}

# Face recognizer (LBPH)
face_recognizer = cv2.face.LBPHFaceRecognizer_create()

def load_faces_for_training(path='assets/images/'):
    images, labels, label_names = [], [], {}
    current_id = 0
    for file in os.listdir(path):
        if file.endswith(('.png', '.jpg')):
            img_path = os.path.join(path, file)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"[WARNING] Could not read image: {img_path}")
                continue
            label = file.split('.')[0]
            if label not in label_names.values():
                label_names[current_id] = label
                current_id += 1
            label_id = [k for k, v in label_names.items() if v == label][0]
            images.append(cv2.resize(img, (200, 200)))
            labels.append(label_id)
            print(f"[LOADED] {file} as label {label_id} -> {label}")
    print("[INFO] Final Labels Map:", label_names)
    return images, np.array(labels), label_names

# Load and train face recognizer
train_imgs, train_labels, label_map = load_faces_for_training()
face_recognizer.train(train_imgs, train_labels)

# Haar Cascade for live face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start webcam
cap = cv2.VideoCapture(0)
print("[INFO] Webcam started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    h, w = frame.shape[:2]

    # Face detection and recognition
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, wf, hf) in faces:
        face = gray[y:y+hf, x:x+wf]
        face_resized = cv2.resize(face, (200, 200))
        label_id, confidence = face_recognizer.predict(face_resized)
        name = label_map[label_id] if confidence < 120 else "Unknown"
        cv2.rectangle(frame, (x, y), (x+wf, y+hf), (255, 0, 0), 2)
        cv2.putText(frame, f"{name} ({round(confidence,1)})", (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

    # Object detection
    blob = cv2.dnn.blobFromImage(frame, size=(300, 300), swapRB=True, crop=False)
    net.setInput(blob)
    detections = net.forward()

    for i in range(detections.shape[2]):
        conf = detections[0, 0, i, 2]
        if conf > 0.4:
            class_id = int(detections[0, 0, i, 1])
            label = class_names[class_id] if class_id < len(class_names) else "Unknown"
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            x1, y1, x2, y2 = box.astype(int)

            # Ignore tiny boxes & allow only known labels
            if (x2 - x1) * (y2 - y1) < 10000 or label not in allowed_objects:
                continue

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    cv2.imshow("Live Face + Object Recognition", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import cv2
#       2 import numpy as np
#       3 import os
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
import numpy as np
import os

# Load COCO class labels
with open('models/coco_class_labels.txt', 'r') as f:
    class_names = f.read().strip().split('\n')
if class_names[0].lower() != 'background':
    class_names.insert(0, 'background')

# Allowed object labels for display
allowed_objects = {'cell phone', 'cup', 'bottle', 'pen', 'remote', 'wallet', 'book'}

# Load DNN object detection model
net = cv2.dnn.readNetFromTensorflow(
    'models/frozen_inference_graph.pb',
    'models/ssd_mobilenet_v2_coco_2018_03_29.pbtxt'
)

# Load face recognizer (LBPH)
face_recognizer = cv2.face.LBPHFaceRecognizer_create()

# Load and train face images
def load_faces_for_training(path='assets/images/'):
    images, labels, label_names = [], [], {}
    name_to_id = {}
    current_id = 0

    for file in os.listdir(path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(path, file)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"[WARNING] Skipping unreadable image: {img_path}")
                continue
            name = os.path.splitext(file)[0].split('_')[0]
            if name not in name_to_id:
                name_to_id[name] = current_id
                label_names[current_id] = name
                current_id += 1
            label_id = name_to_id[name]
            images.append(cv2.resize(img, (200, 200)))
            labels.append(label_id)
            print(f"[LOADED] {file} as {name} (label ID: {label_id})")

    print("[INFO] Final label map:", label_names)
    return images, np.array(labels), label_names

# Train the recognizer
train_imgs, train_labels, label_map = load_faces_for_training()
face_recognizer.train(train_imgs, train_labels)

# Load face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start webcam
cap = cv2.VideoCapture(0)
print("[INFO] Webcam started. Press 'q' to exit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("[ERROR] Frame capture failed.")
        break

    h, w = frame.shape[:2]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Face detection and recognition
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)
    for (x, y, wf, hf) in faces:
        face = gray[y:y+hf, x:x+wf]
        face_resized = cv2.resize(face, (200, 200))
        label_id, confidence = face_recognizer.predict(face_resized)
        name = label_map[label_id] if confidence < 120 else "Unknown"
        cv2.rectangle(frame, (x, y), (x+wf, y+hf), (255, 0, 0), 2)
        cv2.putText(frame, f"{name} ({round(confidence, 1)})", (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

    # Object detection using DNN
    blob = cv2.dnn.blobFromImage(frame, size=(300, 300), swapRB=True, crop=False)
    net.setInput(blob)
    detections = net.forward()

    for i in range(detections.shape[2]):
        conf = detections[0, 0, i, 2]
        if conf > 0.4:
            class_id = int(detections[0, 0, i, 1])
            label = class_names[class_id] if class_id < len(class_names) else "Unknown"
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            x1, y1, x2, y2 = box.astype(int)
            area = (x2 - x1) * (y2 - y1)

            if area > 2000 and label in allowed_objects:
                print(f"[OBJECT] {label} ({conf:.2f}) at [{x1},{y1},{x2},{y2}]")
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    cv2.imshow("Face + Object Recognition", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [LOADED] JLO_1.jpg as JLO (label ID: 0)
# [LOADED] JLO_2.jpg as JLO (label ID: 0)
# [LOADED] Pradyumna_1.jpg as Pradyumna (label ID: 1)
# [LOADED] Pradyumna_2.jpg as Pradyumna (label ID: 1)
# [LOADED] Vyshaak_1.jpg as Vyshaak (label ID: 2)
# [LOADED] Vyshaak_2.jpg as Vyshaak (label ID: 2)
# [LOADED] Vyshaak_3.jpg as Vyshaak (label ID: 2)
# [INFO] Final label map: {0: 'JLO', 1: 'Pradyumna', 2: 'Vyshaak'}
# [INFO] Webcam started. Press 'q' to exit.
# [OBJECT] cell phone (0.72) at [88,3,457,435]
# [OBJECT] cell phone (0.42) at [93,22,455,404]
# [OBJECT] cell phone (0.40) at [91,40,435,461]
# [OBJECT] cell phone (0.69) at [82,49,451,424]
# [OBJECT] cell phone (0.73) at [97,22,447,403]
# [OBJECT] cell phone (0.43) at [80,15,448,419]
# [OBJECT] cell phone (0.46) at [63,6,462,466]
# [OBJECT] cell phone (0.69) at [74,13,445,466]
# [OBJECT] cell phone (0.44) at [87,19,470,463]
# [OBJECT] cell phone (0.49) at [108,40,454,456]
# [OBJECT] cell phone (0.43) at [114,22,482,464]
# [OBJECT] cell phone (0.50) at [145,50,413,425]
# [OBJECT] cell phone (0.50) at [142,58,419,400]
# [OBJECT] cell phone (0.54) at [113,28,477,464]
# [OBJECT] cell phone (0.53) at [124,32,487,464]
# [OBJECT] cell phone (0.50) at [128,32,452,462]
# [OBJECT] cell phone (0.42) at [131,63,421,399]
# [OBJECT] cell phone (0.47) at [113,28,509,470]
# [OBJECT] cell phone (0.43) at [120,20,519,466]
# [OBJECT] cell phone (0.49) at [116,19,486,463]
# [OBJECT] cell phone (0.51) at [118,26,479,467]
# [OBJECT] cell phone (0.59) at [122,25,474,464]
# [OBJECT] cell phone (0.44) at [114,27,489,466]
# [OBJECT] cell phone (0.68) at [117,29,474,468]
# [OBJECT] cell phone (0.66) at [122,31,516,466]
# [OBJECT] cell phone (0.77) at [126,24,488,468]
# [OBJECT] cell phone (0.44) at [117,28,530,471]
# [OBJECT] cell phone (0.62) at [122,27,481,467]
# [OBJECT] cell phone (0.63) at [128,29,475,467]
# [OBJECT] cell phone (0.75) at [122,34,477,467]
# [OBJECT] cell phone (0.85) at [125,39,490,470]
# [OBJECT] cell phone (0.66) at [132,23,505,467]
# [OBJECT] cell phone (0.64) at [116,24,493,466]
# [OBJECT] cell phone (0.46) at [146,36,436,434]
# [OBJECT] cell phone (0.58) at [152,47,429,402]
# [OBJECT] cell phone (0.41) at [138,53,422,401]
# [OBJECT] cell phone (0.41) at [138,62,420,380]
# [OBJECT] cell phone (0.68) at [175,54,432,379]
# [OBJECT] cell phone (0.47) at [157,56,422,399]
# [OBJECT] cell phone (0.41) at [164,14,423,372]
# [OBJECT] cell phone (0.51) at [160,55,434,380]
# [OBJECT] cell phone (0.68) at [173,106,439,339]
# [OBJECT] cell phone (0.59) at [128,11,516,453]
# [OBJECT] cell phone (0.41) at [182,16,450,384]
# [OBJECT] cell phone (0.43) at [171,57,438,353]
# [OBJECT] cell phone (0.53) at [185,54,451,361]
# [OBJECT] cell phone (0.50) at [139,3,552,464]
# [OBJECT] cell phone (0.56) at [172,59,430,378]
# [OBJECT] cell phone (0.63) at [167,59,425,387]
# [OBJECT] cell phone (0.57) at [160,53,425,370]
# [OBJECT] cell phone (0.43) at [164,52,442,399]
# [OBJECT] cell phone (0.55) at [132,8,518,459]
# [OBJECT] cell phone (0.47) at [171,51,457,376]
# [OBJECT] cell phone (0.46) at [120,3,508,464]
# [OBJECT] cell phone (0.41) at [152,48,438,399]
# [OBJECT] cell phone (0.42) at [156,52,435,387]
# [OBJECT] cell phone (0.42) at [175,45,440,397]
# [OBJECT] cell phone (0.41) at [158,43,436,395]
# [OBJECT] cell phone (0.42) at [170,55,435,370]
# [OBJECT] cell phone (0.48) at [167,56,442,374]
# [OBJECT] cell phone (0.44) at [129,11,515,460]
# [OBJECT] cell phone (0.45) at [155,41,436,403]
# [OBJECT] cell phone (0.42) at [134,10,507,459]
# [OBJECT] cell phone (0.76) at [170,57,440,382]
# [OBJECT] cell phone (0.52) at [145,10,517,456]
# [OBJECT] cell phone (0.54) at [176,59,433,355]
# [OBJECT] cell phone (0.51) at [171,53,438,375]
# [OBJECT] cell phone (0.43) at [167,61,445,365]
# [OBJECT] cell phone (0.44) at [180,31,454,404]
# [OBJECT] cell phone (0.65) at [176,49,431,353]
# [OBJECT] cell phone (0.55) at [173,40,440,389]
# [OBJECT] cell phone (0.60) at [176,49,437,386]
# [OBJECT] cell phone (0.66) at [185,32,446,384]
# [OBJECT] cell phone (0.40) at [144,8,512,459]
# [OBJECT] cell phone (0.48) at [176,58,442,374]
# [OBJECT] cell phone (0.54) at [174,30,445,403]
# [OBJECT] cell phone (0.74) at [180,42,446,386]
# [OBJECT] cell phone (0.78) at [165,19,445,407]
# [OBJECT] cell phone (0.65) at [164,29,451,409]
# [OBJECT] cell phone (0.46) at [165,52,440,369]
# [OBJECT] cell phone (0.47) at [167,57,441,365]
# [OBJECT] cell phone (0.47) at [175,54,439,390]
# [OBJECT] cell phone (0.62) at [174,48,450,379]
# [OBJECT] cell phone (0.67) at [184,48,448,400]
# [OBJECT] cell phone (0.63) at [167,42,454,406]
# [OBJECT] cell phone (0.56) at [136,9,523,465]
# [OBJECT] cell phone (0.53) at [163,26,451,443]
# [OBJECT] cell phone (0.74) at [171,32,447,416]
# [OBJECT] cell phone (0.84) at [162,37,452,403]
# [OBJECT] cell phone (0.45) at [160,33,451,440]
# [OBJECT] cell phone (0.48) at [167,62,438,381]
# [OBJECT] cell phone (0.47) at [158,52,440,386]
# [OBJECT] cell phone (0.46) at [162,54,441,400]
# [OBJECT] cell phone (0.49) at [150,29,456,436]
# [OBJECT] cell phone (0.80) at [162,41,447,432]
# [OBJECT] cell phone (0.62) at [140,8,473,467]
# [OBJECT] cell phone (0.75) at [150,31,446,443]
# [OBJECT] cell phone (0.61) at [157,30,444,454]
# [OBJECT] cell phone (0.71) at [132,11,481,470]
# [OBJECT] cell phone (0.61) at [144,7,467,463]
# [OBJECT] cell phone (0.60) at [153,5,470,460]
# [OBJECT] cell phone (0.78) at [170,29,440,426]
# [OBJECT] cell phone (0.74) at [161,22,439,433]
# [OBJECT] cell phone (0.59) at [157,22,447,453]
# [OBJECT] cell phone (0.68) at [163,24,444,449]
# [OBJECT] cell phone (0.64) at [147,15,515,461]
# [OBJECT] cell phone (0.44) at [186,17,438,408]
# [OBJECT] cell phone (0.77) at [173,39,437,414]
# [OBJECT] cell phone (0.55) at [147,12,531,463]
# [OBJECT] cell phone (0.75) at [171,24,449,413]
# [OBJECT] cell phone (0.84) at [178,29,440,423]
# [OBJECT] cell phone (0.62) at [138,10,534,462]
# [OBJECT] cell phone (0.68) at [146,11,547,463]
# [OBJECT] cell phone (0.65) at [174,34,452,424]
# [OBJECT] cell phone (0.55) at [168,26,448,425]
# [OBJECT] cell phone (0.54) at [146,10,558,462]
# [OBJECT] cell phone (0.72) at [175,29,447,418]
# [OBJECT] cell phone (0.71) at [169,26,448,419]
# [OBJECT] cell phone (0.73) at [173,26,442,409]
# [OBJECT] cell phone (0.51) at [144,7,525,459]
# [OBJECT] cell phone (0.49) at [162,28,446,437]
# [OBJECT] cell phone (0.52) at [163,32,446,439]
# [OBJECT] cell phone (0.52) at [174,29,448,430]
# [OBJECT] cell phone (0.62) at [173,28,448,425]
# [OBJECT] cell phone (0.84) at [176,28,442,408]
# [OBJECT] cell phone (0.69) at [172,33,446,434]
# [OBJECT] cell phone (0.76) at [175,29,431,410]
# [OBJECT] cell phone (0.64) at [175,103,425,319]
# [OBJECT] cell phone (0.46) at [134,12,506,452]
# [OBJECT] cell phone (0.49) at [127,10,520,463]
# [OBJECT] cell phone (0.44) at [124,6,523,473]
# [OBJECT] cell phone (0.55) at [117,10,488,460]
# [OBJECT] cell phone (0.52) at [117,13,475,455]
# [OBJECT] cell phone (0.49) at [128,55,433,364]
# [OBJECT] cell phone (0.53) at [109,10,489,459]
# [OBJECT] cell phone (0.56) at [130,1,469,456]
# [OBJECT] cell phone (0.46) at [140,4,475,452]
# [OBJECT] cell phone (0.48) at [110,14,487,460]
# [OBJECT] cell phone (0.59) at [113,17,481,446]
# [OBJECT] cell phone (0.43) at [123,10,473,455]
# [OBJECT] cell phone (0.55) at [75,29,448,405]
# [OBJECT] cell phone (0.66) at [46,57,505,474]
# [OBJECT] cell phone (0.44) at [105,21,451,445]
# [OBJECT] cell phone (0.69) at [107,18,463,454]
# [OBJECT] cell phone (0.44) at [142,9,428,337]
# [OBJECT] cell phone (0.74) at [130,1,456,464]
# [OBJECT] cell phone (0.53) at [184,13,430,342]
# [OBJECT] cell phone (0.42) at [185,9,414,322]
# [OBJECT] cell phone (0.46) at [140,8,471,473]
# [OBJECT] cell phone (0.48) at [154,22,440,446]
# [OBJECT] cell phone (0.48) at [180,9,417,390]
# [OBJECT] cell phone (0.45) at [151,21,461,457]
# [OBJECT] cell phone (0.51) at [161,18,433,448]
# [OBJECT] cell phone (0.74) at [160,17,415,443]
# [OBJECT] cell phone (0.44) at [160,21,422,450]
# [OBJECT] cell phone (0.50) at [154,20,415,451]
# [OBJECT] cell phone (0.57) at [161,19,412,447]
# [OBJECT] cell phone (0.66) at [163,18,415,442]
# [OBJECT] cell phone (0.60) at [162,22,421,431]
# [OBJECT] cell phone (0.48) at [160,20,409,442]
# [OBJECT] cell phone (0.65) at [164,18,408,437]
# [OBJECT] cell phone (0.57) at [168,19,414,437]
# [OBJECT] cell phone (0.50) at [165,21,414,445]
# [OBJECT] cell phone (0.42) at [169,23,418,451]
# [OBJECT] cell phone (0.48) at [162,20,403,444]
# [OBJECT] cell phone (0.65) at [169,23,408,432]
# [OBJECT] cell phone (0.44) at [167,24,421,451]
# [OBJECT] cell phone (0.49) at [169,24,415,441]
# [OBJECT] cell phone (0.46) at [166,22,415,444]
# [OBJECT] cell phone (0.46) at [168,23,410,437]
# [OBJECT] cell phone (0.57) at [166,20,402,446]
# [OBJECT] cell phone (0.62) at [177,22,412,429]
# [OBJECT] cell phone (0.56) at [169,24,412,438]
# [OBJECT] cell phone (0.54) at [166,23,411,440]
# [OBJECT] cell phone (0.70) at [168,26,405,434]
# [OBJECT] cell phone (0.54) at [167,23,411,447]
# [OBJECT] cell phone (0.61) at [171,26,410,439]
# [OBJECT] cell phone (0.45) at [162,23,410,445]
# [OBJECT] cell phone (0.71) at [173,28,410,425]
# [OBJECT] cell phone (0.66) at [164,22,410,445]
# [OBJECT] cell phone (0.95) at [198,37,386,420]
# [OBJECT] cell phone (0.95) at [192,29,389,424]
# [OBJECT] cell phone (0.40) at [154,22,399,442]
# [OBJECT] cell phone (0.62) at [157,21,399,440]
# [OBJECT] cell phone (0.42) at [150,27,398,444]
# [OBJECT] cell phone (0.44) at [149,17,398,449]
# [OBJECT] cell phone (0.47) at [159,21,399,447]
# [OBJECT] cell phone (0.44) at [150,25,403,449]
# [OBJECT] cell phone (0.54) at [159,26,396,438]
# [OBJECT] cell phone (0.44) at [153,26,398,442]
# [OBJECT] cell phone (0.41) at [149,24,400,451]
# [OBJECT] cell phone (0.98) at [199,20,378,419]
# [OBJECT] cell phone (0.97) at [195,28,376,421]
# [OBJECT] cell phone (0.71) at [161,19,394,443]
# [OBJECT] cell phone (0.75) at [174,28,385,423]
# [OBJECT] cell phone (0.49) at [149,25,396,452]
# [OBJECT] cell phone (0.98) at [190,25,372,411]
# [OBJECT] cell phone (0.42) at [153,17,393,445]
# [OBJECT] cell phone (0.60) at [170,24,394,435]
# [OBJECT] cell phone (0.58) at [165,25,394,434]
# [OBJECT] cell phone (0.41) at [196,80,368,392]
# [OBJECT] cell phone (0.97) at [184,21,370,427]
# [OBJECT] cell phone (0.40) at [159,17,398,451]
# [OBJECT] cell phone (0.40) at [155,26,393,437]
# [OBJECT] cell phone (0.47) at [160,21,397,450]
# [OBJECT] cell phone (0.40) at [149,21,397,443]
# [OBJECT] cell phone (0.56) at [171,24,403,435]
# [OBJECT] cell phone (0.61) at [172,25,398,441]
# [OBJECT] cell phone (0.81) at [167,24,395,435]
# [OBJECT] cell phone (0.57) at [163,25,400,444]
# [OBJECT] cell phone (0.57) at [169,38,408,434]
# [OBJECT] cell phone (0.52) at [195,98,364,395]
# [OBJECT] cell phone (0.45) at [149,23,402,441]
# [OBJECT] cell phone (0.55) at [151,25,396,431]
# [OBJECT] cell phone (0.61) at [159,22,397,436]
# [OBJECT] cell phone (0.51) at [158,16,400,442]
# [OBJECT] cell phone (0.60) at [157,18,398,444]
# [OBJECT] cell phone (0.50) at [159,12,397,446]
# [OBJECT] cell phone (0.47) at [164,20,392,439]
# [OBJECT] cell phone (0.58) at [159,17,395,441]
# [OBJECT] cell phone (0.53) at [160,21,400,444]
# [OBJECT] cell phone (0.50) at [150,22,390,416]
# [OBJECT] cell phone (0.45) at [162,30,400,446]
# [OBJECT] cell phone (0.58) at [128,57,297,369]
# [OBJECT] cell phone (0.94) at [70,27,237,335]
# [OBJECT] cell phone (0.93) at [57,29,233,326]
# [OBJECT] cell phone (0.93) at [51,36,225,323]
# [OBJECT] cell phone (0.86) at [35,31,217,320]
# [OBJECT] cell phone (0.88) at [30,19,211,321]
# [OBJECT] cell phone (0.89) at [26,26,204,317]
# [OBJECT] cell phone (0.92) at [28,24,205,318]
# [OBJECT] cell phone (0.94) at [30,16,207,318]
# [OBJECT] cell phone (0.96) at [34,23,205,313]
# [OBJECT] cell phone (0.98) at [33,21,203,313]
# [OBJECT] cell phone (0.95) at [28,33,203,312]
# [OBJECT] cell phone (0.97) at [30,36,203,310]
# [OBJECT] cell phone (0.98) at [21,49,197,301]
# [OBJECT] cell phone (1.00) at [29,49,190,308]
# [OBJECT] cell phone (1.00) at [32,57,181,315]
# [OBJECT] cell phone (0.98) at [28,78,174,303]
# [OBJECT] cell phone (0.97) at [11,79,158,329]

# %%
import cv2
import numpy as np
import os

# Load COCO class labels
with open('models/coco_class_labels.txt', 'r') as f:
    class_names = f.read().strip().split('\n')
if class_names[0].lower() != 'background':
    class_names.insert(0, 'background')

# Allowed object labels for display
allowed_objects = {'cell phone', 'cup', 'bottle', 'pen', 'remote', 'wallet', 'book'}

# Load DNN object detection model
net = cv2.dnn.readNetFromTensorflow(
    'models/frozen_inference_graph.pb',
    'models/ssd_mobilenet_v2_coco_2018_03_29.pbtxt'
)

# Load face recognizer (LBPH)
face_recognizer = cv2.face.LBPHFaceRecognizer_create()

# Load and train face images
def load_faces_for_training(path='assets/images/'):
    images, labels, label_names = [], [], {}
    name_to_id = {}
    current_id = 0

    for file in os.listdir(path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(path, file)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"[WARNING] Skipping unreadable image: {img_path}")
                continue
            name = os.path.splitext(file)[0].split('_')[0]
            if name not in name_to_id:
                name_to_id[name] = current_id
                label_names[current_id] = name
                current_id += 1
            label_id = name_to_id[name]
            images.append(cv2.resize(img, (200, 200)))
            labels.append(label_id)
            print(f"[LOADED] {file} as {name} (label ID: {label_id})")

    print("[INFO] Final label map:", label_names)
    return images, np.array(labels), label_names

# Train the recognizer
train_imgs, train_labels, label_map = load_faces_for_training()
face_recognizer.train(train_imgs, train_labels)

# Load face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start webcam
cap = cv2.VideoCapture(0)
print("[INFO] Webcam started. Press 'q' to exit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("[ERROR] Frame capture failed.")
        break

    h, w = frame.shape[:2]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Face detection and recognition
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)
    for (x, y, wf, hf) in faces:
        face = gray[y:y+hf, x:x+wf]
        face_resized = cv2.resize(face, (200, 200))
        label_id, confidence = face_recognizer.predict(face_resized)
        name = label_map[label_id] if confidence < 120 else "Unknown"
        cv2.rectangle(frame, (x, y), (x+wf, y+hf), (255, 0, 0), 2)
        cv2.putText(frame, f"{name} ({round(confidence, 1)})", (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

    # Object detection using DNN
    blob = cv2.dnn.blobFromImage(frame, size=(300, 300), swapRB=True, crop=False)
    net.setInput(blob)
    detections = net.forward()

    for i in range(detections.shape[2]):
        conf = detections[0, 0, i, 2]
        if conf > 0.4:
            class_id = int(detections[0, 0, i, 1])
            label = class_names[class_id] if class_id < len(class_names) else "Unknown"
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            x1, y1, x2, y2 = box.astype(int)
            area = (x2 - x1) * (y2 - y1)

            if area > 2000 and label in allowed_objects:
                print(f"[OBJECT] {label} ({conf:.2f}) at [{x1},{y1},{x2},{y2}]")
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    cv2.imshow("Face + Object Recognition", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [LOADED] Pradyumna_1.jpg as Pradyumna (label ID: 0)
# [LOADED] Pradyumna_2.jpg as Pradyumna (label ID: 0)
# [LOADED] Vyshaak_1.jpg as Vyshaak (label ID: 1)
# [LOADED] Vyshaak_2.jpg as Vyshaak (label ID: 1)
# [LOADED] Vyshaak_3.jpg as Vyshaak (label ID: 1)
# [INFO] Final label map: {0: 'Pradyumna', 1: 'Vyshaak'}
# [INFO] Webcam started. Press 'q' to exit.
# [OBJECT] cell phone (0.92) at [136,253,279,477]
# [OBJECT] cell phone (0.61) at [119,240,271,475]
# [OBJECT] cell phone (0.69) at [115,197,268,471]
# [OBJECT] cell phone (0.40) at [193,170,332,423]
# [OBJECT] cell phone (0.63) at [197,193,342,435]
# [OBJECT] cell phone (0.49) at [193,193,351,415]
# [OBJECT] cell phone (0.51) at [197,204,347,424]
# [OBJECT] cell phone (0.42) at [151,152,312,429]
# [OBJECT] cell phone (0.65) at [103,143,328,461]
# [OBJECT] cell phone (0.48) at [83,149,321,462]
# [OBJECT] cell phone (0.89) at [91,145,325,461]
# [OBJECT] cell phone (0.80) at [98,147,321,450]
# [OBJECT] cell phone (0.86) at [95,139,328,455]
# [OBJECT] cell phone (0.86) at [91,152,328,455]
# [OBJECT] cell phone (0.85) at [91,153,320,447]
# [OBJECT] cell phone (0.52) at [85,163,319,442]
# [OBJECT] cell phone (0.60) at [71,154,323,452]
# [OBJECT] cell phone (0.75) at [69,143,321,453]
# [OBJECT] cell phone (0.53) at [30,119,362,473]
# [OBJECT] cell phone (0.44) at [36,122,367,480]
# [OBJECT] cell phone (0.47) at [89,186,367,487]
# [OBJECT] cell phone (0.45) at [98,183,354,480]
# [OBJECT] cell phone (0.42) at [88,171,351,483]
# [OBJECT] cell phone (0.57) at [94,164,340,483]
# [OBJECT] cell phone (0.42) at [102,132,349,467]
# [OBJECT] cell phone (0.41) at [101,134,350,458]
# [OBJECT] cell phone (0.49) at [102,128,351,460]
# [OBJECT] cell phone (0.54) at [108,146,365,484]
# [OBJECT] cell phone (0.52) at [130,144,355,436]
# [OBJECT] cell phone (0.50) at [148,157,335,449]
# [OBJECT] cell phone (0.45) at [50,141,546,478]
# [OBJECT] cell phone (0.44) at [58,134,554,478]
# [OBJECT] cell phone (0.46) at [160,172,352,456]
# [OBJECT] cell phone (0.46) at [156,190,329,465]
# [OBJECT] cell phone (0.60) at [149,195,327,468]
# [OBJECT] cell phone (0.48) at [146,194,315,473]
# [OBJECT] cell phone (0.56) at [141,213,310,479]
# [OBJECT] cell phone (0.62) at [99,240,308,474]
# [OBJECT] cell phone (0.69) at [104,219,309,473]
# [OBJECT] cell phone (0.70) at [94,225,311,474]
# [OBJECT] cell phone (0.85) at [100,221,306,473]
# [OBJECT] cell phone (0.83) at [100,212,300,472]
# [OBJECT] cell phone (0.81) at [94,204,312,470]
# [OBJECT] cell phone (0.87) at [100,199,309,471]
# [OBJECT] cell phone (0.77) at [94,198,304,470]
# [OBJECT] cell phone (0.60) at [98,199,301,469]
# [OBJECT] cell phone (0.47) at [115,228,289,464]
# [OBJECT] cell phone (0.58) at [102,204,295,473]
# [OBJECT] cell phone (0.61) at [116,228,286,460]
# [OBJECT] cell phone (0.77) at [98,198,297,467]
# [OBJECT] cell phone (0.58) at [95,199,298,472]
# [OBJECT] cell phone (0.42) at [96,203,306,467]
# [OBJECT] cell phone (0.68) at [96,200,309,469]
# [OBJECT] cell phone (0.68) at [100,190,309,472]
# [OBJECT] cell phone (0.65) at [125,207,291,463]
# [OBJECT] cell phone (0.57) at [120,224,290,451]
# [OBJECT] cell phone (0.48) at [103,212,277,469]
# [OBJECT] cell phone (0.40) at [124,204,284,461]
# [OBJECT] cell phone (0.52) at [121,207,287,459]
# [OBJECT] cell phone (0.44) at [118,211,286,459]
# [OBJECT] cell phone (0.47) at [120,197,280,471]
# [OBJECT] cell phone (0.42) at [117,199,284,466]
# [OBJECT] cell phone (0.82) at [107,192,289,464]
# [OBJECT] cell phone (0.59) at [118,205,286,467]
# [OBJECT] cell phone (0.48) at [123,211,281,469]
# [OBJECT] cell phone (0.70) at [95,200,305,467]
# [OBJECT] cell phone (0.84) at [111,198,303,467]
# [OBJECT] cell phone (0.72) at [101,205,308,470]
# [OBJECT] cell phone (0.72) at [96,196,316,471]
# [OBJECT] cell phone (0.86) at [107,198,316,473]
# [OBJECT] cell phone (0.66) at [100,198,314,474]
# [OBJECT] cell phone (0.67) at [103,199,309,473]
# [OBJECT] cell phone (0.78) at [99,201,307,469]
# [OBJECT] cell phone (0.82) at [105,202,301,471]
# [OBJECT] cell phone (0.79) at [100,201,312,471]
# [OBJECT] cell phone (0.55) at [99,201,315,475]
# [OBJECT] cell phone (0.56) at [101,205,310,473]
# [OBJECT] cell phone (0.48) at [119,223,300,472]
# [OBJECT] cell phone (0.53) at [103,205,317,474]
# [OBJECT] cell phone (0.67) at [110,205,315,476]
# [OBJECT] cell phone (0.68) at [127,215,299,470]
# [OBJECT] cell phone (0.61) at [130,222,299,471]
# [OBJECT] cell phone (0.84) at [134,210,300,466]
# [OBJECT] cell phone (0.88) at [134,210,300,471]
# [OBJECT] cell phone (0.93) at [139,211,300,470]
# [OBJECT] cell phone (0.88) at [130,215,300,471]
# [OBJECT] cell phone (0.79) at [129,214,298,467]
# [OBJECT] cell phone (0.86) at [141,220,301,468]
# [OBJECT] cell phone (0.78) at [128,221,300,469]
# [OBJECT] cell phone (0.82) at [129,216,300,473]
# [OBJECT] cell phone (0.74) at [133,218,301,474]
# [OBJECT] cell phone (0.73) at [132,220,299,468]
# [OBJECT] cell phone (0.81) at [130,220,303,474]
# [OBJECT] cell phone (0.86) at [130,220,299,466]
# [OBJECT] cell phone (0.73) at [134,216,299,471]
# [OBJECT] cell phone (0.52) at [139,224,297,468]
# [OBJECT] cell phone (0.82) at [139,223,299,467]
# [OBJECT] cell phone (0.83) at [133,226,301,479]
# [OBJECT] cell phone (0.83) at [133,221,301,474]
# [OBJECT] cell phone (0.84) at [130,221,300,473]
# [OBJECT] cell phone (0.81) at [132,224,301,476]
# [OBJECT] cell phone (0.77) at [135,217,303,476]
# [OBJECT] cell phone (0.57) at [122,205,325,475]
# [OBJECT] cell phone (0.71) at [142,218,309,465]
# [OBJECT] cell phone (0.50) at [117,202,328,475]
# [OBJECT] cell phone (0.74) at [121,205,323,476]
# [OBJECT] cell phone (0.70) at [124,203,320,477]
# [OBJECT] cell phone (0.64) at [119,200,328,478]
# [OBJECT] cell phone (0.72) at [123,205,324,478]
# [OBJECT] cell phone (0.65) at [121,206,317,476]
# [OBJECT] cell phone (0.67) at [139,227,306,467]
# [OBJECT] cell phone (0.70) at [139,230,308,480]
# [OBJECT] cell phone (0.78) at [115,213,318,477]
# [OBJECT] cell phone (0.86) at [133,224,300,471]
# [OBJECT] cell phone (0.64) at [114,212,318,474]
# [OBJECT] cell phone (0.86) at [113,214,316,473]
# [OBJECT] cell phone (0.92) at [122,224,302,474]
# [OBJECT] cell phone (0.82) at [116,214,318,474]
# [OBJECT] cell phone (0.83) at [127,230,302,476]
# [OBJECT] cell phone (0.76) at [125,228,299,475]
# [OBJECT] cell phone (0.79) at [114,211,320,474]
# [OBJECT] cell phone (0.81) at [121,224,297,475]
# [OBJECT] cell phone (0.78) at [125,230,300,476]
# [OBJECT] cell phone (0.74) at [120,214,315,474]
# [OBJECT] cell phone (0.75) at [111,210,314,473]
# [OBJECT] cell phone (0.61) at [108,215,315,474]
# [OBJECT] cell phone (0.87) at [108,214,314,472]
# [OBJECT] cell phone (0.78) at [106,212,320,474]
# [OBJECT] cell phone (0.68) at [112,209,314,472]
# [OBJECT] cell phone (0.65) at [105,209,319,473]
# [OBJECT] cell phone (0.66) at [105,212,316,474]
# [OBJECT] cell phone (0.78) at [107,212,313,473]
# [OBJECT] cell phone (0.88) at [106,209,316,474]
# [OBJECT] cell phone (0.78) at [109,207,314,472]
# [OBJECT] cell phone (0.65) at [105,213,310,473]
# [OBJECT] cell phone (0.69) at [103,211,315,473]
# [OBJECT] cell phone (0.82) at [107,209,312,472]
# [OBJECT] cell phone (0.77) at [104,211,317,475]
# [OBJECT] cell phone (0.52) at [102,212,310,471]
# [OBJECT] cell phone (0.68) at [104,213,310,472]
# [OBJECT] cell phone (0.85) at [106,212,316,474]
# [OBJECT] cell phone (0.70) at [99,213,320,475]
# [OBJECT] cell phone (0.66) at [101,214,314,473]
# [OBJECT] cell phone (0.73) at [101,213,317,475]
# [OBJECT] cell phone (0.91) at [106,207,315,475]
# [OBJECT] cell phone (0.77) at [101,216,311,473]
# [OBJECT] cell phone (0.79) at [108,210,310,473]
# [OBJECT] cell phone (0.83) at [104,209,313,475]
# [OBJECT] cell phone (0.62) at [104,212,315,475]
# [OBJECT] cell phone (0.75) at [104,215,311,470]
# [OBJECT] cell phone (0.77) at [104,210,312,471]
# [OBJECT] cell phone (0.77) at [100,212,311,471]
# [OBJECT] cell phone (0.84) at [101,215,312,472]
# [OBJECT] cell phone (0.77) at [100,213,309,472]
# [OBJECT] cell phone (0.76) at [106,213,305,471]
# [OBJECT] cell phone (0.84) at [105,211,308,473]
# [OBJECT] cell phone (0.92) at [107,209,306,474]
# [OBJECT] cell phone (0.82) at [102,212,311,472]
# [OBJECT] cell phone (0.80) at [103,213,308,473]
# [OBJECT] cell phone (0.75) at [101,213,307,472]
# [OBJECT] cell phone (0.72) at [104,215,309,473]
# [OBJECT] cell phone (0.74) at [100,217,308,471]
# [OBJECT] cell phone (0.71) at [99,218,306,470]
# [OBJECT] cell phone (0.77) at [97,220,304,472]
# [OBJECT] cell phone (0.89) at [99,219,304,474]
# [OBJECT] cell phone (0.83) at [94,222,310,475]
# [OBJECT] cell phone (0.81) at [96,217,309,472]
# [OBJECT] cell phone (0.73) at [103,206,305,471]
# [OBJECT] cell phone (0.79) at [97,209,303,468]
# [OBJECT] cell phone (0.82) at [97,200,307,471]
# [OBJECT] cell phone (0.72) at [97,197,301,472]
# [OBJECT] cell phone (0.54) at [107,192,309,471]
# [OBJECT] cell phone (0.58) at [129,215,295,461]
# [OBJECT] cell phone (0.52) at [128,210,299,458]
# [OBJECT] cell phone (0.43) at [128,199,301,461]
# [OBJECT] cell phone (0.56) at [121,177,323,476]
# [OBJECT] cell phone (0.48) at [72,141,508,484]
# [OBJECT] cell phone (0.41) at [157,147,336,435]
# [OBJECT] cell phone (0.61) at [62,128,542,477]
# [OBJECT] cell phone (0.50) at [56,120,545,474]
# [OBJECT] cell phone (0.58) at [93,120,502,477]
# [OBJECT] cell phone (0.85) at [135,103,494,467]
# [OBJECT] cell phone (0.57) at [129,96,489,462]
# [OBJECT] cell phone (0.87) at [139,96,482,463]
# [OBJECT] cell phone (0.94) at [145,89,477,449]
# [OBJECT] cell phone (0.93) at [145,95,490,453]
# [OBJECT] cell phone (0.81) at [152,75,431,453]
# [OBJECT] cell phone (0.90) at [166,78,440,457]
# [OBJECT] cell phone (0.89) at [165,75,442,452]
# [OBJECT] cell phone (0.67) at [126,76,478,472]
# [OBJECT] cell phone (0.87) at [133,62,461,470]
# [OBJECT] cell phone (0.76) at [106,63,505,469]
# [OBJECT] cell phone (0.83) at [134,58,462,467]
# [OBJECT] cell phone (0.88) at [123,60,456,460]
# [OBJECT] cell phone (0.40) at [70,61,491,472]
# [OBJECT] cell phone (0.65) at [123,73,459,464]
# [OBJECT] cell phone (0.66) at [122,68,467,448]
# [OBJECT] cell phone (0.65) at [91,78,459,465]
# [OBJECT] cell phone (0.63) at [161,128,434,473]
# [OBJECT] cell phone (0.70) at [113,46,480,462]
# [OBJECT] cell phone (0.66) at [111,40,488,466]
# [OBJECT] cell phone (0.94) at [141,59,471,466]
# [OBJECT] cell phone (0.93) at [151,48,466,456]
# [OBJECT] cell phone (0.77) at [137,60,475,462]
# [OBJECT] cell phone (0.93) at [135,43,469,459]
# [OBJECT] cell phone (0.94) at [135,49,469,462]
# [OBJECT] cell phone (0.86) at [133,45,479,462]
# [OBJECT] cell phone (0.81) at [130,50,472,457]
# [OBJECT] cell phone (0.83) at [119,38,477,456]
# [OBJECT] cell phone (0.90) at [127,55,464,460]
# [OBJECT] cell phone (0.92) at [121,37,471,462]
# [OBJECT] cell phone (0.76) at [134,48,466,459]
# [OBJECT] cell phone (0.83) at [119,51,484,462]
# [OBJECT] cell phone (0.95) at [127,43,474,464]
# [OBJECT] cell phone (0.91) at [114,36,484,461]
# [OBJECT] cell phone (0.83) at [106,41,494,461]
# [OBJECT] cell phone (0.91) at [106,31,490,461]
# [OBJECT] cell phone (0.89) at [103,45,492,467]
# [OBJECT] cell phone (0.93) at [105,34,485,460]
# [OBJECT] cell phone (0.95) at [131,46,465,463]
# [OBJECT] cell phone (0.86) at [109,49,481,466]
# [OBJECT] cell phone (0.94) at [124,38,476,465]
# [OBJECT] cell phone (0.88) at [112,52,472,465]
# [OBJECT] cell phone (0.64) at [53,38,502,475]
# [OBJECT] cell phone (0.53) at [98,53,492,456]
# [OBJECT] cell phone (0.82) at [87,40,502,473]
# [OBJECT] cell phone (0.80) at [138,77,472,470]
# [OBJECT] cell phone (0.95) at [122,32,503,474]
# [OBJECT] cell phone (0.94) at [148,47,492,476]
# [OBJECT] cell phone (0.95) at [124,34,505,474]
# [OBJECT] cell phone (0.91) at [124,42,520,472]
# [OBJECT] cell phone (0.93) at [118,35,534,473]
# [OBJECT] cell phone (0.94) at [138,32,524,474]
# [OBJECT] cell phone (0.93) at [133,27,522,474]
# [OBJECT] cell phone (0.80) at [159,79,510,467]
# [OBJECT] cell phone (0.89) at [113,38,538,471]
# [OBJECT] cell phone (0.95) at [151,25,503,472]
# [OBJECT] cell phone (0.93) at [118,26,532,471]
# [OBJECT] cell phone (0.94) at [165,22,512,469]
# [OBJECT] cell phone (0.94) at [172,28,514,465]
# [OBJECT] cell phone (0.93) at [129,26,533,474]
# [OBJECT] cell phone (0.90) at [169,72,514,471]
# [OBJECT] cell phone (0.89) at [145,21,527,473]
# [OBJECT] cell phone (0.92) at [148,25,522,472]
# [OBJECT] cell phone (0.93) at [152,18,526,472]
# [OBJECT] cell phone (0.93) at [124,17,538,472]
# [OBJECT] cell phone (0.89) at [139,19,519,472]
# [OBJECT] cell phone (0.80) at [134,22,518,471]
# [OBJECT] cell phone (0.93) at [144,17,529,473]
# [OBJECT] cell phone (0.93) at [137,19,530,472]
# [OBJECT] cell phone (0.56) at [151,74,520,477]
# [OBJECT] cell phone (0.94) at [146,17,529,472]
# [OBJECT] cell phone (0.89) at [115,22,526,471]
# [OBJECT] cell phone (0.86) at [125,14,541,473]
# [OBJECT] cell phone (0.91) at [134,18,529,472]
# [OBJECT] cell phone (0.93) at [127,23,528,471]
# [OBJECT] cell phone (0.92) at [150,13,525,472]
# [OBJECT] cell phone (0.94) at [128,21,528,472]
# [OBJECT] cell phone (0.43) at [66,68,537,460]
# [OBJECT] cell phone (0.89) at [120,32,539,471]
# [OBJECT] cell phone (0.50) at [63,64,529,458]
# [OBJECT] cell phone (0.66) at [116,44,523,455]
# [OBJECT] cell phone (0.94) at [123,16,531,474]
# [OBJECT] cell phone (0.94) at [138,10,530,474]
# [OBJECT] cell phone (0.67) at [106,41,535,451]
# [OBJECT] cell phone (0.60) at [55,23,544,462]
# [OBJECT] cell phone (0.54) at [46,22,548,467]
# [OBJECT] cell phone (0.46) at [106,40,539,453]
# [OBJECT] cell phone (0.51) at [67,53,552,459]
# [OBJECT] cell phone (0.56) at [44,60,548,458]
# [OBJECT] cell phone (0.68) at [43,21,542,466]
# [OBJECT] cell phone (0.54) at [48,24,542,465]
# [OBJECT] cell phone (0.51) at [49,26,542,463]
# [OBJECT] cell phone (0.56) at [44,56,547,457]
# [OBJECT] cell phone (0.41) at [51,56,552,456]
# [OBJECT] cell phone (0.41) at [62,49,546,458]
# [OBJECT] cell phone (0.52) at [54,53,545,460]
# [OBJECT] cell phone (0.59) at [61,56,541,457]
# [OBJECT] cell phone (0.50) at [52,54,544,457]
# [OBJECT] cell phone (0.67) at [82,37,527,450]
# [OBJECT] cell phone (0.66) at [54,53,534,461]
# [OBJECT] cell phone (0.66) at [89,41,519,454]
# [OBJECT] cell phone (0.63) at [87,39,527,451]
# [OBJECT] cell phone (0.55) at [46,25,543,464]
# [OBJECT] cell phone (0.64) at [102,52,533,457]
# [OBJECT] cell phone (0.61) at [47,23,546,460]
# [OBJECT] cell phone (0.61) at [59,58,542,461]
# [OBJECT] cell phone (0.50) at [44,55,546,461]
# [OBJECT] cell phone (0.64) at [82,38,524,456]
# [OBJECT] cell phone (0.48) at [37,22,535,466]
# [OBJECT] cell phone (0.45) at [29,16,539,468]
# [OBJECT] cell phone (0.40) at [34,18,541,466]
# [OBJECT] cell phone (0.40) at [33,17,539,466]
# [OBJECT] cell phone (0.47) at [36,15,539,467]
# [OBJECT] cell phone (0.56) at [29,17,541,469]
# [OBJECT] cell phone (0.67) at [62,27,528,460]
# [OBJECT] cell phone (0.55) at [65,25,527,461]
# [OBJECT] cell phone (0.68) at [56,31,525,457]
# [OBJECT] cell phone (0.62) at [65,31,524,461]
# [OBJECT] cell phone (0.43) at [59,38,525,461]
# [OBJECT] cell phone (0.66) at [77,39,521,458]
# [OBJECT] cell phone (0.67) at [77,38,519,459]
# [OBJECT] cell phone (0.48) at [69,38,512,460]
# [OBJECT] cell phone (0.42) at [65,36,515,457]
# [OBJECT] cell phone (0.43) at [70,39,514,462]
# [OBJECT] cell phone (0.62) at [69,35,510,465]
# [OBJECT] cell phone (0.95) at [84,38,517,476]
# [OBJECT] cell phone (0.94) at [80,44,508,475]
# [OBJECT] cell phone (0.97) at [124,45,476,473]
# [OBJECT] cell phone (0.97) at [116,51,493,473]
# [OBJECT] cell phone (0.79) at [78,65,486,473]
# [OBJECT] cell phone (0.87) at [62,67,486,474]
# [OBJECT] cell phone (0.93) at [74,65,482,472]
# [OBJECT] cell phone (0.95) at [87,64,482,471]
# [OBJECT] cell phone (0.97) at [93,67,466,470]
# [OBJECT] cell phone (0.93) at [81,62,472,472]
# [OBJECT] cell phone (0.91) at [83,79,510,474]
# [OBJECT] cell phone (0.88) at [93,64,475,470]
# [OBJECT] cell phone (0.95) at [100,82,474,471]
# [OBJECT] cell phone (0.86) at [95,74,470,474]
# [OBJECT] cell phone (0.95) at [127,80,453,473]
# [OBJECT] cell phone (0.97) at [99,80,481,469]
# [OBJECT] cell phone (0.95) at [93,73,483,467]
# [OBJECT] cell phone (0.85) at [107,72,476,468]
# [OBJECT] cell phone (0.46) at [92,105,477,478]
# [OBJECT] cell phone (0.46) at [100,94,466,477]
# [OBJECT] cell phone (0.89) at [108,84,477,476]
# [OBJECT] cell phone (0.91) at [107,87,475,472]
# [OBJECT] cell phone (0.58) at [108,93,465,475]
# [OBJECT] cell phone (0.90) at [92,83,488,473]
# [OBJECT] cell phone (0.55) at [103,95,464,476]
# [OBJECT] cell phone (0.96) at [119,84,467,471]
# [OBJECT] cell phone (0.42) at [106,108,468,478]
# [OBJECT] cell phone (0.50) at [109,109,466,478]
# [OBJECT] cell phone (0.93) at [100,87,479,478]
# [OBJECT] cell phone (0.93) at [105,86,467,471]
# [OBJECT] cell phone (0.90) at [123,94,463,471]
# [OBJECT] cell phone (0.54) at [115,107,466,477]
# [OBJECT] cell phone (0.95) at [123,93,469,471]
# [OBJECT] cell phone (0.94) at [113,83,468,471]
# [OBJECT] cell phone (0.95) at [124,98,466,468]
# [OBJECT] cell phone (0.84) at [110,89,470,471]
# [OBJECT] cell phone (0.92) at [126,87,473,470]
# [OBJECT] cell phone (0.69) at [83,82,497,453]
# [OBJECT] cell phone (0.90) at [118,86,478,471]
# [OBJECT] cell phone (0.61) at [108,108,463,476]
# [OBJECT] cell phone (0.60) at [107,110,464,475]
# [OBJECT] cell phone (0.74) at [122,97,460,468]
# [OBJECT] cell phone (0.93) at [129,89,459,468]
# [OBJECT] cell phone (0.91) at [146,101,452,475]
# [OBJECT] cell phone (0.92) at [135,106,458,475]
# [OBJECT] cell phone (0.93) at [127,100,458,476]
# [OBJECT] cell phone (0.90) at [140,107,452,476]
# [OBJECT] cell phone (0.90) at [133,108,466,473]
# [OBJECT] cell phone (0.73) at [127,115,475,475]
# [OBJECT] cell phone (0.73) at [138,88,482,482]
# [OBJECT] cell phone (0.60) at [136,90,489,484]
# [OBJECT] cell phone (0.79) at [191,132,420,477]
# [OBJECT] cell phone (0.55) at [125,90,486,471]
# [OBJECT] cell phone (0.67) at [108,106,480,466]
# [OBJECT] cell phone (0.64) at [122,115,472,469]
# [OBJECT] cell phone (0.47) at [178,171,423,475]
# [OBJECT] cell phone (0.66) at [140,91,476,481]
# [OBJECT] cell phone (0.49) at [182,140,413,476]
# [OBJECT] cell phone (0.79) at [141,93,491,479]
# [OBJECT] cell phone (0.81) at [147,90,476,482]
# [OBJECT] cell phone (0.85) at [146,93,484,485]
# [OBJECT] cell phone (0.87) at [194,148,419,477]
# [OBJECT] cell phone (0.80) at [145,91,481,482]
# [OBJECT] cell phone (0.80) at [159,138,439,481]
# [OBJECT] cell phone (0.90) at [193,182,410,477]
# [OBJECT] cell phone (0.78) at [143,107,449,465]
# [OBJECT] cell phone (0.68) at [109,226,485,477]
# [OBJECT] cell phone (0.74) at [168,140,440,480]
# [OBJECT] cell phone (0.92) at [150,96,481,486]
# [OBJECT] cell phone (0.71) at [145,97,473,476]
# [OBJECT] cell phone (0.70) at [182,155,429,477]
# [OBJECT] cell phone (0.40) at [120,95,503,468]
# [OBJECT] cell phone (0.61) at [141,98,480,483]
# [OBJECT] cell phone (0.43) at [191,145,420,479]
# [OBJECT] cell phone (0.59) at [130,99,464,470]
# [OBJECT] cell phone (0.49) at [130,101,481,470]
# [OBJECT] cell phone (0.71) at [135,121,458,467]
# [OBJECT] cell phone (0.78) at [149,97,472,476]
# [OBJECT] cell phone (0.68) at [144,95,478,479]
# [OBJECT] cell phone (0.71) at [147,94,481,478]
# [OBJECT] cell phone (0.77) at [147,93,474,480]
# [OBJECT] cell phone (0.66) at [187,150,408,477]
# [OBJECT] cell phone (0.69) at [139,93,462,473]
# [OBJECT] cell phone (0.79) at [131,94,473,480]
# [OBJECT] cell phone (0.80) at [151,98,471,478]
# [OBJECT] cell phone (0.64) at [135,99,477,473]
# [OBJECT] cell phone (0.68) at [139,116,462,469]
# [OBJECT] cell phone (0.89) at [191,179,414,479]
# [OBJECT] cell phone (0.74) at [140,115,452,467]
# [OBJECT] cell phone (0.79) at [195,173,441,477]
# [OBJECT] cell phone (0.59) at [137,101,487,470]
# [OBJECT] cell phone (0.83) at [162,100,482,482]
# [OBJECT] cell phone (0.85) at [161,98,481,478]
# [OBJECT] cell phone (0.72) at [142,95,480,483]
# [OBJECT] cell phone (0.81) at [143,94,479,481]
# [OBJECT] cell phone (0.63) at [144,94,476,482]
# [OBJECT] cell phone (0.41) at [184,151,418,476]
# [OBJECT] cell phone (0.76) at [157,101,474,475]
# [OBJECT] cell phone (0.52) at [194,178,432,478]
# [OBJECT] cell phone (0.79) at [142,98,481,469]
# [OBJECT] cell phone (0.84) at [144,112,469,468]
# [OBJECT] cell phone (0.74) at [149,92,482,479]
# [OBJECT] cell phone (0.55) at [191,167,433,478]
# [OBJECT] cell phone (0.83) at [129,114,477,469]
# [OBJECT] cell phone (0.69) at [124,111,489,470]
# [OBJECT] cell phone (0.65) at [131,105,468,471]
# [OBJECT] cell phone (0.74) at [149,96,478,478]
# [OBJECT] cell phone (0.62) at [189,190,437,479]
# [OBJECT] cell phone (0.76) at [141,92,481,482]
# [OBJECT] cell phone (0.63) at [185,162,415,477]
# [OBJECT] cell phone (0.69) at [155,94,475,478]
# [OBJECT] cell phone (0.59) at [202,180,415,478]
# [OBJECT] cell phone (0.86) at [183,197,430,471]
# [OBJECT] cell phone (0.72) at [156,100,459,468]
# [OBJECT] cell phone (0.83) at [155,96,476,474]
# [OBJECT] cell phone (0.80) at [147,110,463,466]
# [OBJECT] cell phone (0.53) at [86,216,509,476]
# [OBJECT] cell phone (0.86) at [199,175,424,475]
# [OBJECT] cell phone (0.84) at [147,114,462,468]
# [OBJECT] cell phone (0.58) at [129,227,501,478]
# [OBJECT] cell phone (0.95) at [223,180,425,475]
# [OBJECT] cell phone (0.84) at [157,120,467,467]
# [OBJECT] cell phone (0.98) at [206,170,426,474]
# [OBJECT] cell phone (0.91) at [158,231,488,472]
# [OBJECT] cell phone (0.79) at [169,95,465,472]
# [OBJECT] cell phone (0.85) at [215,176,436,473]
# [OBJECT] cell phone (0.71) at [154,113,467,468]
# [OBJECT] cell phone (0.70) at [162,232,497,472]
# [OBJECT] cell phone (0.80) at [219,173,445,475]
# [OBJECT] cell phone (0.74) at [158,101,482,463]
# [OBJECT] cell phone (0.58) at [164,226,506,474]
# [OBJECT] cell phone (0.89) at [210,179,450,479]
# [OBJECT] cell phone (0.72) at [160,98,484,478]
# [OBJECT] cell phone (0.79) at [215,178,456,476]
# [OBJECT] cell phone (0.74) at [154,128,502,473]
# [OBJECT] cell phone (0.87) at [215,173,448,479]
# [OBJECT] cell phone (0.76) at [166,99,481,478]
# [OBJECT] cell phone (0.44) at [128,223,511,479]
# [OBJECT] cell phone (0.93) at [217,185,433,474]
# [OBJECT] cell phone (0.70) at [160,120,466,463]
# [OBJECT] cell phone (0.58) at [147,228,502,476]
# [OBJECT] cell phone (0.94) at [203,180,430,475]
# [OBJECT] cell phone (0.70) at [168,104,469,466]
# [OBJECT] cell phone (0.95) at [199,177,439,471]
# [OBJECT] cell phone (0.76) at [158,109,481,466]
# [OBJECT] cell phone (0.91) at [199,165,458,479]
# [OBJECT] cell phone (0.62) at [135,105,503,472]
# [OBJECT] cell phone (0.90) at [219,164,449,480]
# [OBJECT] cell phone (0.76) at [152,123,496,470]
# [OBJECT] cell phone (0.93) at [211,185,436,478]
# [OBJECT] cell phone (0.80) at [164,232,491,472]
# [OBJECT] cell phone (0.61) at [161,102,464,466]
# [OBJECT] cell phone (0.93) at [205,176,450,479]
# [OBJECT] cell phone (0.72) at [147,117,491,467]
# [OBJECT] cell phone (0.94) at [210,169,450,479]
# [OBJECT] cell phone (0.88) at [150,121,494,472]
# [OBJECT] cell phone (0.90) at [211,170,451,480]
# [OBJECT] cell phone (0.78) at [159,102,488,465]
# [OBJECT] cell phone (0.83) at [200,148,446,480]
# [OBJECT] cell phone (0.81) at [141,100,493,470]
# [OBJECT] cell phone (0.53) at [60,194,534,474]
# [OBJECT] cell phone (0.89) at [203,142,447,480]
# [OBJECT] cell phone (0.63) at [130,198,513,475]
# [OBJECT] cell phone (0.81) at [202,169,448,482]
# [OBJECT] cell phone (0.59) at [127,121,498,466]
# [OBJECT] cell phone (0.94) at [213,153,449,478]
# [OBJECT] cell phone (0.71) at [140,199,511,478]
# [OBJECT] cell phone (0.94) at [215,175,446,478]
# [OBJECT] cell phone (0.82) at [149,127,486,472]
# [OBJECT] cell phone (0.93) at [213,184,438,480]
# [OBJECT] cell phone (0.71) at [156,105,475,464]
# [OBJECT] cell phone (0.60) at [145,226,506,482]
# [OBJECT] cell phone (0.91) at [209,180,446,481]
# [OBJECT] cell phone (0.76) at [152,223,505,473]
# [OBJECT] cell phone (0.42) at [119,107,516,465]
# [OBJECT] cell phone (0.92) at [208,170,435,475]
# [OBJECT] cell phone (0.89) at [149,128,483,473]
# [OBJECT] cell phone (0.87) at [205,152,456,481]
# [OBJECT] cell phone (0.69) at [144,107,504,468]
# [OBJECT] cell phone (0.81) at [200,163,448,478]
# [OBJECT] cell phone (0.70) at [146,101,492,476]
# [OBJECT] cell phone (0.51) at [74,207,520,477]
# [OBJECT] cell phone (0.87) at [148,101,498,475]
# [OBJECT] cell phone (0.93) at [209,179,446,475]
# [OBJECT] cell phone (0.87) at [147,126,491,472]
# [OBJECT] cell phone (0.95) at [198,189,436,472]
# [OBJECT] cell phone (0.84) at [149,123,475,472]
# [OBJECT] cell phone (0.94) at [194,190,448,472]
# [OBJECT] cell phone (0.68) at [149,113,481,463]
# [OBJECT] cell phone (0.86) at [190,161,446,474]
# [OBJECT] cell phone (0.60) at [122,108,500,465]
# [OBJECT] cell phone (0.78) at [200,198,450,471]
# [OBJECT] cell phone (0.62) at [146,129,482,470]
# [OBJECT] cell phone (0.90) at [211,170,448,480]
# [OBJECT] cell phone (0.73) at [161,104,483,467]
# [OBJECT] cell phone (0.49) at [146,221,512,479]
# [OBJECT] cell phone (0.95) at [211,172,440,476]
# [OBJECT] cell phone (0.83) at [158,223,492,471]
# [OBJECT] cell phone (0.40) at [122,109,509,463]
# [OBJECT] cell phone (0.96) at [204,172,445,477]
# [OBJECT] cell phone (0.81) at [165,101,477,458]
# [OBJECT] cell phone (0.76) at [141,224,504,479]
# [OBJECT] cell phone (0.88) at [204,157,458,481]
# [OBJECT] cell phone (0.61) at [134,203,515,477]
# [OBJECT] cell phone (0.88) at [186,168,449,475]
# [OBJECT] cell phone (0.49) at [124,112,500,469]
# [OBJECT] cell phone (0.82) at [147,131,491,475]
# [OBJECT] cell phone (0.90) at [206,172,443,478]
# [OBJECT] cell phone (0.81) at [143,124,479,470]
# [OBJECT] cell phone (0.94) at [180,172,442,474]
# [OBJECT] cell phone (0.55) at [127,108,479,462]
# [OBJECT] cell phone (0.86) at [203,146,459,482]
# [OBJECT] cell phone (0.63) at [129,105,505,470]
# [OBJECT] cell phone (0.88) at [203,164,452,478]
# [OBJECT] cell phone (0.78) at [144,108,495,472]
# [OBJECT] cell phone (0.94) at [188,159,446,473]
# [OBJECT] cell phone (0.85) at [146,130,502,475]
# [OBJECT] cell phone (0.91) at [185,181,440,475]
# [OBJECT] cell phone (0.50) at [136,123,486,469]
# [OBJECT] cell phone (0.86) at [118,118,501,471]
# [OBJECT] cell phone (0.86) at [146,104,489,469]
# [OBJECT] cell phone (0.86) at [197,168,452,480]
# [OBJECT] cell phone (0.92) at [170,143,456,476]
# [OBJECT] cell phone (0.92) at [155,103,487,464]
# [OBJECT] cell phone (0.94) at [169,123,455,476]
# [OBJECT] cell phone (0.88) at [166,141,450,476]
# [OBJECT] cell phone (0.93) at [207,175,450,478]
# [OBJECT] cell phone (0.68) at [135,210,517,479]
# [OBJECT] cell phone (0.88) at [207,150,449,476]
# [OBJECT] cell phone (0.72) at [141,203,512,475]
# [OBJECT] cell phone (0.94) at [196,187,441,472]
# [OBJECT] cell phone (0.81) at [163,104,476,467]
# [OBJECT] cell phone (0.88) at [208,158,452,479]
# [OBJECT] cell phone (0.74) at [146,113,496,471]
# [OBJECT] cell phone (0.76) at [144,104,491,475]
# [OBJECT] cell phone (0.47) at [75,211,536,475]
# [OBJECT] cell phone (0.40) at [217,148,440,484]
# [OBJECT] cell phone (0.90) at [202,202,437,469]
# [OBJECT] cell phone (0.58) at [165,103,469,467]
# [OBJECT] cell phone (0.89) at [214,177,449,481]
# [OBJECT] cell phone (0.78) at [148,124,497,471]
# [OBJECT] cell phone (0.96) at [199,183,439,470]
# [OBJECT] cell phone (0.68) at [158,106,476,464]
# [OBJECT] cell phone (0.91) at [195,185,442,475]
# [OBJECT] cell phone (0.67) at [152,119,484,463]
# [OBJECT] cell phone (0.84) at [146,102,493,477]
# [OBJECT] cell phone (0.41) at [214,135,438,483]
# [OBJECT] cell phone (0.91) at [218,181,442,476]
# [OBJECT] cell phone (0.77) at [162,121,481,469]
# [OBJECT] cell phone (0.89) at [208,167,440,475]
# [OBJECT] cell phone (0.70) at [152,230,500,474]
# [OBJECT] cell phone (0.94) at [212,166,439,473]
# [OBJECT] cell phone (0.87) at [170,97,472,463]
# [OBJECT] cell phone (0.83) at [153,229,495,470]
# [OBJECT] cell phone (0.90) at [190,170,441,473]
# [OBJECT] cell phone (0.51) at [135,103,488,461]
# [OBJECT] cell phone (0.93) at [194,188,445,471]
# [OBJECT] cell phone (0.52) at [139,103,491,464]
# [OBJECT] cell phone (0.93) at [213,175,435,477]
# [OBJECT] cell phone (0.79) at [175,99,470,464]
# [OBJECT] cell phone (0.76) at [168,237,483,474]
# [OBJECT] cell phone (0.90) at [207,191,444,473]
# [OBJECT] cell phone (0.63) at [163,104,465,468]
# [OBJECT] cell phone (0.62) at [147,243,507,478]
# [OBJECT] cell phone (0.90) at [217,190,436,473]
# [OBJECT] cell phone (0.68) at [166,116,466,465]
# [OBJECT] cell phone (0.54) at [155,237,502,476]
# [OBJECT] cell phone (0.96) at [207,184,433,470]
# [OBJECT] cell phone (0.83) at [154,113,454,467]
# [OBJECT] cell phone (0.71) at [146,236,483,477]
# [OBJECT] cell phone (0.93) at [200,194,433,473]
# [OBJECT] cell phone (0.73) at [164,102,467,468]
# [OBJECT] cell phone (0.90) at [201,149,451,475]
# [OBJECT] cell phone (0.71) at [145,214,509,472]
# [OBJECT] cell phone (0.92) at [193,192,442,471]
# [OBJECT] cell phone (0.59) at [153,106,474,458]
# [OBJECT] cell phone (0.89) at [188,166,447,474]
# [OBJECT] cell phone (0.53) at [140,104,489,462]
# [OBJECT] cell phone (0.91) at [194,194,443,470]
# [OBJECT] cell phone (0.60) at [150,108,479,458]
# [OBJECT] cell phone (0.90) at [189,154,451,476]
# [OBJECT] cell phone (0.91) at [198,176,435,475]
# [OBJECT] cell phone (0.62) at [138,232,486,475]
# [OBJECT] cell phone (0.45) at [133,100,492,458]
# [OBJECT] cell phone (0.90) at [193,190,439,473]
# [OBJECT] cell phone (0.57) at [155,114,474,462]
# [OBJECT] cell phone (0.91) at [218,157,438,477]
# [OBJECT] cell phone (0.76) at [168,100,480,463]
# [OBJECT] cell phone (0.68) at [133,232,513,475]
# [OBJECT] cell phone (0.92) at [193,155,455,474]
# [OBJECT] cell phone (0.84) at [130,217,518,475]
# [OBJECT] cell phone (0.86) at [207,167,447,477]
# [OBJECT] cell phone (0.76) at [137,112,494,470]
# [OBJECT] cell phone (0.76) at [205,156,463,479]
# [OBJECT] cell phone (0.69) at [129,116,516,471]
# [OBJECT] cell phone (0.75) at [199,152,459,478]
# [OBJECT] cell phone (0.60) at [126,118,514,467]
# [OBJECT] cell phone (0.84) at [200,153,465,482]
# [OBJECT] cell phone (0.43) at [117,105,525,468]
# [OBJECT] cell phone (0.90) at [204,160,447,477]
# [OBJECT] cell phone (0.78) at [146,113,500,472]
# [OBJECT] cell phone (0.91) at [195,175,457,480]
# [OBJECT] cell phone (0.64) at [135,122,507,468]
# [OBJECT] cell phone (0.87) at [202,168,452,478]
# [OBJECT] cell phone (0.52) at [137,120,499,465]
# [OBJECT] cell phone (0.84) at [200,173,459,480]
# [OBJECT] cell phone (0.63) at [133,127,514,473]
# [OBJECT] cell phone (0.88) at [191,167,468,480]
# [OBJECT] cell phone (0.85) at [193,154,458,479]
# [OBJECT] cell phone (0.62) at [131,211,515,481]
# [OBJECT] cell phone (0.92) at [185,159,470,478]
# [OBJECT] cell phone (0.86) at [139,144,468,480]
# [OBJECT] cell phone (0.81) at [205,170,458,485]
# [OBJECT] cell phone (0.56) at [137,226,512,481]
# [OBJECT] cell phone (0.94) at [199,172,459,481]
# [OBJECT] cell phone (0.79) at [130,227,508,477]
# [OBJECT] cell phone (0.84) at [190,155,461,482]
# [OBJECT] cell phone (0.72) at [117,208,516,482]
# [OBJECT] cell phone (0.90) at [183,159,463,481]
# [OBJECT] cell phone (0.86) at [191,170,452,479]
# [OBJECT] cell phone (0.44) at [129,121,504,468]
# [OBJECT] cell phone (0.94) at [193,181,454,482]
# [OBJECT] cell phone (0.45) at [125,104,514,469]
# [OBJECT] cell phone (0.68) at [143,135,498,476]
# [OBJECT] cell phone (0.93) at [185,151,465,475]
# [OBJECT] cell phone (0.92) at [184,151,455,476]
# [OBJECT] cell phone (0.85) at [178,160,438,470]
# [OBJECT] cell phone (0.75) at [154,144,428,477]
# [OBJECT] cell phone (0.79) at [140,97,442,474]

# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests>=2.27.1 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from deepface) (2.32.3)
# Requirement already satisfied: numpy>=1.14.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from deepface) (2.0.2)
# Requirement already satisfied: pandas>=0.23.4 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from deepface) (2.2.3)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tqdm>=4.30.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from deepface) (4.67.1)
# Requirement already satisfied: Pillow>=5.2.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from deepface) (11.1.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from deepface) (4.11.0.86)
# Collecting tensorflow>=1.9.0 (from deepface)
#   Downloading tensorflow-2.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting keras>=2.2.0 (from deepface)
#   Downloading keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting Flask>=1.1.2 (from deepface)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting termcolor (from fire>=0.4.0->deepface)
#   Downloading termcolor-3.0.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting Werkzeug>=3.1 (from Flask>=1.1.2->deepface)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Collecting itsdangerous>=2.2 (from Flask>=1.1.2->deepface)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from Flask>=1.1.2->deepface) (8.6.1)
# Requirement already satisfied: beautifulsoup4 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from gdown>=3.10.1->deepface) (4.13.3)
# Requirement already satisfied: filelock in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: packaging in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from gunicorn>=20.1.0->deepface) (24.2)
# Collecting absl-py (from keras>=2.2.0->deepface)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting rich (from keras>=2.2.0->deepface)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=2.2.0->deepface)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting h5py (from keras>=2.2.0->deepface)
#   Downloading h5py-3.13.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting optree (from keras>=2.2.0->deepface)
#   Downloading optree-0.15.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Collecting ml-dtypes (from keras>=2.2.0->deepface)
#   Downloading ml_dtypes-0.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests>=2.27.1->deepface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests>=2.27.1->deepface) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests>=2.27.1->deepface) (2025.1.31)
# Collecting astunparse>=1.6.0 (from tensorflow>=1.9.0->deepface)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow>=1.9.0->deepface)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow>=1.9.0->deepface)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow>=1.9.0->deepface)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow>=1.9.0->deepface)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow>=1.9.0->deepface)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (5.29.4)
# Requirement already satisfied: setuptools in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow>=1.9.0->deepface)
#   Downloading wrapt-1.17.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow>=1.9.0->deepface)
#   Downloading grpcio-1.71.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow>=1.9.0->deepface)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow>=1.9.0->deepface)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: zipp>=3.20 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from importlib-metadata>=3.6->Flask>=1.1.2->deepface) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (3.0.2)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=2.2.0->deepface)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from rich->keras>=2.2.0->deepface) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
# Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.9 MB/s eta 0:00:00
# Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.4 MB/s eta 0:00:006 MB/s eta 0:00:01
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Downloading tensorflow-2.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 MB 8.6 MB/s eta 0:00:000m eta 0:00:010:00:02
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.71.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 7.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading h5py-3.13.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 8.7 MB/s eta 0:00:009.9 MB/s eta 0:00:01m
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 10.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading ml_dtypes-0.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 10.0 MB/s eta 0:00:0031m11.4 MB/s eta 0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.6 MB/s eta 0:00:009 MB/s eta 0:00:01
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 8.8 MB/s eta 0:00:009.1 MB/s eta 0:00:01
# Downloading termcolor-3.0.1-py3-none-any.whl (7.2 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-1.17.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.15.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (397 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 8.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114298 sha256=9bc6c25fef82f4d9408cbfd377f7321da1fa7a4cacf91cb4ad871cd1fdc9c52d
#   Stored in directory: /home/pradyumnakubear/.cache/pip/wheels/3b/ee/ac/319a7b7f331f61050d0d54425079b2a883b445be3c7284a4eb
# Successfully built fire
# Installing collected packages: namex, libclang, flatbuffers, wrapt, Werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, ml-dtypes, mdurl, itsdangerous, h5py, gunicorn, grpcio, google-pasta, gast, astunparse, absl-py, markdown-it-py, markdown, Flask, fire, tensorboard, rich, gdown, flask-cors, keras, tensorflow, mtcnn, retina-face, deepface
# Successfully installed Flask-3.1.0 Werkzeug-3.1.3 absl-py-2.2.2 astunparse-1.6.3 deepface-0.0.93 fire-0.7.0 flask-cors-5.0.1 flatbuffers-25.2.10 gast-0.6.0 gdown-5.2.0 google-pasta-0.2.0 grpcio-1.71.0 gunicorn-23.0.0 h5py-3.13.0 itsdangerous-2.2.0 keras-3.9.2 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 mtcnn-0.1.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.15.0 retina-face-0.0.17 rich-14.0.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.0.1 wrapt-1.17.2
